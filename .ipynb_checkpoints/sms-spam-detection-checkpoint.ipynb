# %% [markdown]
# # SMS SPAM DETECTION

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importing the Dataset

# %%
df = pd.read_csv('spam.csv', encoding='latin1')

# %% [markdown]
# Random dataset sample

# %%
df.sample(5)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 3499  spam  Dorothy@kiefer.com (Bank of Granite issues Str...        NaN
# 853    ham  \AH POOR BABY!HOPE URFEELING BETTERSN LUV! PRO...        NaN
# 1375   ham                            We're finally ready fyi        NaN
# 1495   ham  Hey gals.. Anyone of u going down to e driving...        NaN
# 4354   ham                   Sorry, I can't help you on this.        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3499        NaN        NaN
# 853         NaN        NaN
# 1375        NaN        NaN
# 1495        NaN        NaN
# 4354        NaN        NaN

# %% [markdown]
# Shape of the Dataset

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# # Machine Learning Development Life Cycle
# ## 1. Data Cleaning
# ## 2. EDA {Exploratory Data Analysis}
# ## 3. Text Preprocessing
# ## 4. Model Building
# ## 5. Model Evaluation
# ## 6. Model Improvement
# ## 7. Website Development
# ## 8. Deployment

# %% [markdown]
# #

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# Description of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %% [markdown]
# Dropping the last 3 columns

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 2938  ham        Are you ok. What happen to behave like this
# 377   ham  Well there's not a lot of things happening in ...
# 4365  ham    Mm yes dear look how i am hugging you both. :-P
# 793   ham  Omg I want to scream. I weighed myself and I l...
# 4367  ham  1 I don't have her number and 2 its gonna be a...

# %% [markdown]
# Renaming the columns

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 1654    ham  Wishing you and your family Merry \X\" mas and...
# 171     ham  Hmmm.. Thk sure got time to hop ard... Ya, can...
# 4771    ham  Hi, Mobile no.  &lt;#&gt;  has added you in th...
# 3255    ham  Who were those people ? Were you in a tour ? I...
# 1867    ham  Mmmm ... Fuck ... Not fair ! You know my weakn...

# %% [markdown]
# Converting Label to Numbers for Processing

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### SPAM:1 ,HAM:0

# %% [markdown]
# Checking for missing values

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %% [markdown]
# Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 403

# %% [markdown]
# Removing duplicates

# %%
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Shape Of the dataset after Data cleaning

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## 2.EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %% [markdown]
# ### Data is imbalanced .

# %% [markdown]
# Finding the number of characters, words and sentenses in the messages for furture analysis.

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Characters

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %% [markdown]
# Words

# %%
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %% [markdown]
# Sentences

# %%
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %% [markdown]
# Analysing all Messages

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455407       1.961308
# std         58.236293    13.322448       1.432583
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %% [markdown]
# Analysing only Ham Messages

# %%
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123339       1.815545
# std         56.358207    13.491315       1.364098
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %% [markdown]
# Analysing only Spam Messages

# %%
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.969372
# std         30.137753    7.008418       1.488910
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %% [markdown]
# ### Spam Mesages are longer than Ham messages from our Analysis

# %% [markdown]
# ### Visualizing our Conclusion

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <AxesSubplot:xlabel='num_characters', ylabel='Count'>

# %% [markdown]
# HAM:Blue, SPAM:Red

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <AxesSubplot:xlabel='num_words', ylabel='Count'>

# %% [markdown]
# HAM:Blue, SPAM:Red

# %%
sns.pairplot(df,hue='target')

# %% [markdown]
# ### Correlations between lables

# %%
df.corr()
# Out:
#                   target  num_characters  num_words  num_sentences
# target          1.000000        0.384717   0.262969       0.267602
# num_characters  0.384717        1.000000   0.965784       0.626118
# num_words       0.262969        0.965784   1.000000       0.680882
# num_sentences   0.267602        0.626118   0.680882       1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#df.to_csv('DataAnalysis.csv', index=False)

# %% [markdown]
# ## 3. Data Preprocessing
# - Lower case
# - Tokenization
# - Removing special characters
# - Removing stop words and punctuation
# - Stemming

# %% [markdown]
# ### List of stopwords in English that doesn't contribute to sentence meaning but are only used in sentence formation.

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %% [markdown]
# ### Punctuation marks

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ### Stemming Process

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('driving')
# Out:
# 'drive'

# %% [markdown]
# ## Fnction to perform Text Preprocessing

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    
            
    return " ".join(y)

# %% [markdown]
# ### Example of Text Preprocessing

# %%
transform_text("""
🎉🎉 Congratulations! You've been selected as the lucky winner of our exclusive giveaway! 🎉🎉

Claim your prize now by clicking on the link below:
👉👉 https://www.amazon.com/

Don't miss out on this amazing opportunity to win big! Hurry, before it's too late!""")
# Out:
# 'congratul select lucki winner exclus giveaway claim prize click link http miss amaz opportun win big hurri late'

# %%
transform_text("""
Hi there,
We hope this message finds you well. We wanted to reach out to inform you about an exciting opportunity we have available. Our team is conducting a research experiment and we would greatly appreciate your participation.
""")
# Out:
# 'hi hope messag find well want reach inform excit opportun avail team conduct research experi would greatli appreci particip'

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %% [markdown]
# Adding a feature called transformed text to the dataframe

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %% [markdown]
# ### WordCloud

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %% [markdown]
# #### Most Common Words in a Spam Messages

# %%
wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,9))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,9))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %% [markdown]
# ## Most Common Words in a Spam Message

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
pd.DataFrame(Counter(spam_corpus).most_common(50))
# Out:
#            0    1
# 0       call  320
# 1       free  191
# 2          2  155
# 3        txt  141
# 4       text  122
# 5          u  119
# 6         ur  119
# 7      mobil  114
# 8       stop  104
# 9      repli  103
# 10     claim   98
# 11         4   97
# 12     prize   82
# 13       get   74
# 14       new   64
# 15    servic   64
# 16      tone   63
# 17      send   60
# 18    urgent   57
# 19     nokia   57
# 20   contact   56
# 21     award   55
# 22     phone   52
# 23      cash   51
# 24     pleas   51
# 25      week   49
# 26       win   48
# 27         c   45
# 28   collect   45
# 29       min   45
# 30    custom   42
# 31    messag   42
# 32  guarante   42
# 33       per   41
# 34      chat   38
# 35       tri   37
# 36       msg   35
# 37      draw   35
# 38    number   35
# 39        cs   35
# 40      show   33
# 41     today   33
# 42     offer   33
# 43      line   33
# 44        go   32
# 45    receiv   31
# 46      want   31
# 47    latest   30
# 48   rington   30
# ...

# %%
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Most Common Words in a Ham Message

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35402

# %%
pd.DataFrame(Counter(ham_corpus).most_common(50))
# Out:
#         0    1
# 0       u  883
# 1      go  404
# 2     get  349
# 3      gt  288
# 4      lt  287
# 5       2  284
# 6    come  275
# 7     got  236
# 8    know  236
# 9    like  234
# 10   call  233
# 11   time  219
# 12   love  216
# 13     ok  215
# 14   good  213
# 15   want  208
# 16     ur  197
# 17    day  190
# 18   need  170
# 19    one  165
# 20    lor  159
# 21      4  156
# 22   home  152
# 23  think  149
# 24    see  147
# 25   take  143
# 26  still  143
# 27     da  142
# 28   tell  133
# 29   make  129
# 30    say  127
# 31   back  127
# 32  today  123
# 33   hope  122
# 34    ask  121
# 35  sorri  121
# 36      n  120
# 37   send  120
# 38      r  120
# 39   work  118
# 40   dont  118
# 41   meet  112
# 42     hi  111
# 43   well  109
# 44  thing  109
# 45    wat  108
# 46      k  107
# 47   much  107
# 48  night  107
# 49     oh  106

# %%
from collections import Counter
sns.barplot(pd.DataFrame(Counter(ham_corpus).most_common(30))[0],pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %% [markdown]
# ## 4. Model Building

# %% [markdown]
#  ### Naïve Bayes Classifier
#  ##### The Naïve Bayes classifier is a supervised machine learning algorithm, which is used for classification tasks, like text classification.

# %% [markdown]
# Vectorization
# Text Vectorization using Bag of Words
# tfidf vectorization {Term frequency Inverse document frequency (TFIDF) }

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
# Experimentation:
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#X = scaler.fit_transform(X)
# appending the num_character col to X
#X = np.hstack((X,df['num_characters'].values.reshape(-1,1)))

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %% [markdown]
# Train:80%, Test Set :20%

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# ## Naive Bayes Algorithms for Classifciation
# ### 1.Gaussian Naive Bayes
# ### 2.Multinomial Naive Bayes
# ### 3.Bernoulli Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %% [markdown]
# ## Multinomial Naive Bayes with tfidf vectorization is the best model.

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))

# %% [markdown]
# END
